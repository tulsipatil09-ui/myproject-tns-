# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %% [markdown]
# Downloads a pre-built list of common meaningless words like "is", "the", "and", "a" that carry no useful information and are typically removed before NLP processing.

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rehan.qureshi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Tokenization
#     - Word tokenization
#     - Sentence tokenization

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt')

# Downloads a pre-trained sentence and word tokenizer model that NLTK needs to split text into words or sentences using word_tokenize().
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rehan.qureshi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
s = 'We are learning natural language processing'
word_tokenize(s)
# Out:
# ['We', 'are', 'learning', 'natural', 'language', 'processing']

# %%
s = 'We are learning natural language processing we are LEARNING NATURAL LANGUAGE toolkit'
word_tokenize(s)
# Out:
# ['We',
#  'are',
#  'learning',
#  'natural',
#  'language',
#  'processing',
#  'we',
#  'are',
#  'LEARNING',
#  'NATURAL',
#  'LANGUAGE',
#  'toolkit']

# %%
s = 'We are learning natural language processing we are LEARNING NATURAL LANGUAGE toolkit'
word_tokenize(s.lower())
# Out:
# ['we',
#  'are',
#  'learning',
#  'natural',
#  'language',
#  'processing',
#  'we',
#  'are',
#  'learning',
#  'natural',
#  'language',
#  'toolkit']

# %%
s = "Don't worry if it is not making sense now, later it won't make sense either."
word_tokenize(s.lower())
# Out:
# ['do',
#  "n't",
#  'worry',
#  'if',
#  'it',
#  'is',
#  'not',
#  'making',
#  'sense',
#  'now',
#  ',',
#  'later',
#  'it',
#  'wo',
#  "n't",
#  'make',
#  'sense',
#  'either',
#  '.']

# %%
s = """We have learned word tokenization.
Next we will learn sentence tokenization.
There are many options for tokenization using nltk"""

word_tokenize(s.lower())
# Out:
# ['we',
#  'have',
#  'learned',
#  'word',
#  'tokenization',
#  '.',
#  'next',
#  'we',
#  'will',
#  'learn',
#  'sentence',
#  'tokenization',
#  '.',
#  'there',
#  'are',
#  'many',
#  'options',
#  'for',
#  'tokenization',
#  'using',
#  'nltk']

# %%
# WordPunctTokenizer
from nltk.tokenize import WordPunctTokenizer
tokenizer = WordPunctTokenizer()

# %% [markdown]
# WordPunctTokenizer splits text into tokens by separating words and punctuation as individual tokens — "don't" → ["don", "'", "t"].

# %%
s = "You shouldn't procrastinate ypur projects"
tokenizer.tokenize(s.lower())
# Out:
# ['you', 'shouldn', "'", 't', 'procrastinate', 'ypur', 'projects']

# %% [markdown]
# ## Sentence Tokenization

# %%
from nltk.tokenize import sent_tokenize

# %%
s = """We have learned word tokenization. 
Next we will learn sentence tokenization.
There are many options for tokenization using nltk"""

sent_tokenize(s.lower())
# Out:
# ['we have learned word tokenization.',
#  'next we will learn sentence tokenization.',
#  'there are many options for tokenization using nltk']

# %% [markdown]
# ## Filtering Stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rehan.qureshi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
s = 'Hello how are you where have you been dead i guess'
filtered_words = []
for word in s.split():
    if word not in stop_words:
        filtered_words.append(word)
        
' '.join(filtered_words)
# Out:
# 'Hello dead guess'

# %%
filtered_words = [word for word in s.split() if word not in stop_words]
' '.join(filtered_words)
# Out:
# 'Hello dead guess'

# %% [markdown]
# ## Stemming

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
stemmer.stem('breaking')
# Out:
# 'break'

# %%
stemmer.stem('Writing')
# Out:
# 'write'

# %%
stemmer.stem('troubling')
# Out:
# 'troubl'

# %%
print(stemmer.stem('breaks'))
print(stemmer.stem('breaking'))
print(stemmer.stem('broke'))
print(stemmer.stem('broken'))
print(stemmer.stem('changes'))
print(stemmer.stem('changed'))
print(stemmer.stem('changing'))
print(stemmer.stem('writes'))
print(stemmer.stem('writing'))
print(stemmer.stem('wrote'))
print(stemmer.stem('running'))
print(stemmer.stem('ran'))
print(stemmer.stem('run'))
print(stemmer.stem('trouble'))
print(stemmer.stem('troubling'))
print(stemmer.stem('troubles'))
print(stemmer.stem('troubled'))
print(stemmer.stem('cats'))
print(stemmer.stem('knives'))
print(stemmer.stem('leaves'))
print(stemmer.stem('jumping'))
print(stemmer.stem('jumped'))
# Out:
# break
# break
# broke
# broken
# chang
# chang
# chang
# write
# write
# wrote
# run
# ran
# run
# troubl
# troubl
# troubl
# troubl
# cat
# knive
# leav
# jump
# jump

# %%
s = """We have learned word tokenization.
We have learned how to filter stopwords.
Now we will learn about sentence tokenization.
In Sentence tokenization a sentence is treated as a single unit rather than a word.
Learning natural language processing maybe confusing but it is fun.
"""

stem_words = [stemmer.stem(word) for word in s.split()]
stem_words
# Out:
# ['we',
#  'have',
#  'learn',
#  'word',
#  'tokenization.',
#  'we',
#  'have',
#  'learn',
#  'how',
#  'to',
#  'filter',
#  'stopwords.',
#  'now',
#  'we',
#  'will',
#  'learn',
#  'about',
#  'sentenc',
#  'tokenization.',
#  'in',
#  'sentenc',
#  'token',
#  'a',
#  'sentenc',
#  'is',
#  'treat',
#  'as',
#  'a',
#  'singl',
#  'unit',
#  'rather',
#  'than',
#  'a',
#  'word.',
#  'learn',
#  'natur',
#  'languag',
#  'process',
#  'mayb',
#  'confus',
#  'but',
#  'it',
#  'is',
#  'fun.']

# %% [markdown]
# ## Lemmatization

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rehan.qureshi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
lemmatizer.lemmatize('breaks')
# Out:
# 'break'

# %%
lemmatizer.lemmatize('break', pos = 'v')
# Out:
# 'break'

# %%
print(lemmatizer.lemmatize('breaks',  pos = 'v'))
print(lemmatizer.lemmatize('breaking',  pos = 'v'))
print(lemmatizer.lemmatize('broke',  pos = 'v'))
print(lemmatizer.lemmatize('broken',  pos = 'v'))
print(lemmatizer.lemmatize('changes',  pos = 'v'))
print(lemmatizer.lemmatize('changed', pos = 'v'))
print(lemmatizer.lemmatize('changing', pos = 'v'))
print(lemmatizer.lemmatize('writes', pos = 'v'))
print(lemmatizer.lemmatize('writing', pos = 'v'))
print(lemmatizer.lemmatize('wrote', pos = 'v'))
print(lemmatizer.lemmatize('running', pos = 'v'))
print(lemmatizer.lemmatize('ran', pos = 'v'))
print(lemmatizer.lemmatize('run', pos = 'v'))
print(lemmatizer.lemmatize('trouble', pos = 'v'))
print(lemmatizer.lemmatize('troubling', pos = 'v'))
print(lemmatizer.lemmatize('troubles', pos = 'v'))
print(lemmatizer.lemmatize('troubled', pos = 'v'))
print(lemmatizer.lemmatize('cats', pos = 'v'))
print(lemmatizer.lemmatize('knives'))
print(lemmatizer.lemmatize('leaves'))
print(lemmatizer.lemmatize('jumping', pos = 'v'))
print(lemmatizer.lemmatize('jumped', pos = 'v'))
# Out:
# break
# break
# break
# break
# change
# change
# change
# write
# write
# write
# run
# run
# run
# trouble
# trouble
# trouble
# trouble
# cat
# knife
# leaf
# jump
# jump

# %% [markdown]
# ## POS tagging   (part of speech tagging)

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\rehan.qureshi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
s = 'He is running'
words = s.split()
words
# Out:
# ['He', 'is', 'running']

# %% [markdown]
# pos_tag assigns a grammatical label to every word — telling you whether each word is a noun, verb, adjective, pronoun etc.

# %%
from nltk import pos_tag
pos_tag(words)
# Out:
# [('He', 'PRP'), ('is', 'VBZ'), ('running', 'VBG')]

# %% [markdown]
# ### Tags
# - CC	coordinating conjunction
# - CD	cardinal digit
# - DT	determiner
# - EX	existential there
# - FW	foreign word
# - IN	preposition/subordinating conjunction
# - JJ	This NLTK POS Tag is an adjective (large)
# - JJR	adjective, comparative (larger)
# - JJS	adjective, superlative (largest)
# - LS	list market
# - MD	modal (could, will)
# - NN	noun, singular (cat, tree)
# - NNS	noun plural (desks)
# - NNP	proper noun, singular (sarah)
# - NNPS	proper noun, plural (indians or americans)
# - PDT	predeterminer (all, both, half)
# - POS	possessive ending (parent\ ‘s)
# - PRP	personal pronoun (hers, herself, him, himself)
# - RB	adverb (occasionally, swiftly)
# - RBR	adverb, comparative (greater)
# - RBS	adverb, superlative (biggest)
# - RP	particle (about)
# - TO	infinite marker (to)
# - UH	interjection (goodbye)
# - VB	verb (ask)
# - VBG	verb gerund (judging)
# - VBD	verb past tense (pleaded)
# - VBN	verb past participle (reunified)
# - VBP	verb, present tense not 3rd person singular(wrap)
# - VBZ	verb, present tense with 3rd person singular (bases)
# - WDT	wh-determiner (that, what)
# - WP	wh- pronoun (who)
# - WRB	wh- adverb (how)
# - PRP$	possessive pronoun (her, his, mine, my, our )

# %%
s = """There were three friends and they were wearing scarves,
they were shivering in the snow,
they were singing a song as it was one of there hobbies"""

words = word_tokenize(s)
nltk.pos_tag(words)
# Out:
# [('There', 'EX'),
#  ('were', 'VBD'),
#  ('three', 'CD'),
#  ('friends', 'NNS'),
#  ('and', 'CC'),
#  ('they', 'PRP'),
#  ('were', 'VBD'),
#  ('wearing', 'VBG'),
#  ('scarves', 'NNS'),
#  (',', ','),
#  ('they', 'PRP'),
#  ('were', 'VBD'),
#  ('shivering', 'VBG'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('snow', 'NN'),
#  (',', ','),
#  ('they', 'PRP'),
#  ('were', 'VBD'),
#  ('singing', 'VBG'),
#  ('a', 'DT'),
#  ('song', 'NN'),
#  ('as', 'IN'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('there', 'EX'),
#  ('hobbies', 'NNS')]
